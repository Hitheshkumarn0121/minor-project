# %%
import csv
from tkinter import *
import tkinter
from tkinter import ttk


filepath =("C:\\Users\\hithe\\Downloads\\city_day.csv")
File = open(filepath)
Reader = csv.reader(File)
Data = list(Reader)



list_of_cities= []
for x in list(range(0, len(Data))):
    list_of_cities.append(Data[x][0])
    
    
root = tkinter.Tk()
root.title('AIR QUALITY INDEX ANALYSIS OF CITIES')
root.config(bg='#446644')
root.geometry("750x250")


lb1 = Listbox(root,bg='#FFFF00',width=200, height=18)

lb1.grid(row=0,column=0)

my_scrollbar = ttk.Scrollbar(root,orient=VERTICAL,command=lb1.yview)
my_scrollbar.grid(row=0,column=1,sticky='ns')

lb1['yscrollcommand']=my_scrollbar.set

for x,y in enumerate(list_of_cities):
    lb1.insert(x,y)

    

def retrieve():
    index = lb1.curselection()[0]
    citylabel2.config(text = Data[index][0])
    Datelabel2.config(text = Data[index][1])
    PM2label2.config(text = Data[index][2])
    PM10label2.config(text = Data[index][3])
    NOlabel2.config(text = Data[index][4])
    NO2label2.config(text = Data[index][5])
    Noxlabel2.config(text = Data[index][6])
    NH3label2.config(text = Data[index][7])
    COlabel2.config(text = Data[index][8])
    SO2label2.config(text = Data[index][9])
    O3label2.config(text = Data[index][10])
    Benzenelabel2.config(text = Data[index][11])
    Toluenelabel2.config(text = Data[index][12])
    Xylenelabel2.config(text = Data[index][13])
    AQIlabel2.config(text = Data[index][14])
    AQIbucketlabel2.config(text = Data[index][15])
    
    print(index)
    return None
    
button1= Button(root,text="Retrive",bd=5,bg='#7FFF00',fg='blue',command=retrieve)
button1.grid(row=5,column=0)

citylabel=Label(root,fg='#0000FF',text="City",width=5,bg='#F5DEB3').grid(row=1,column=0,sticky="w")
Datelabel=Label(root,fg='#0000FF',text="Date",width=5).grid(row=2,column=0,sticky="w")
PM2label=Label(root,fg='#0000FF',text="PM2.5",width=5).grid(row=3,column=0,sticky="w")
PM10label=Label(root,fg='#0000FF',text="PM10",width=5).grid(row=4,column=0,sticky="w")
NOlabel=Label(root,fg='#0000FF',text="NO",width=5).grid(row=5,column=0,sticky="w")
NO2label=Label(root,fg='#0000FF',text="NO2",width=5).grid(row=6,column=0,sticky="w")
Noxlabel=Label(root,fg='#0000FF',text="Nox",width=5).grid(row=7,column=0,sticky="w")
NH3label=Label(root,fg='#0000FF',text="NH3",width=5).grid(row=8,column=0,sticky="w")
COlabel=Label(root,fg='#0000FF',text="CO",width=5).grid(row=9,column=0,sticky="w")
SO2label=Label(root,fg='#0000FF',text="SO2",width=5).grid(row=10,column=0,sticky="w")
O3label=Label(root,fg='#0000FF',text="O3",width=5).grid(row=11,column=0,sticky="w")
Benzenelabel=Label(root,fg='#0000FF',text="Benzene",width=7).grid(row=12,column=0,sticky="w")
Toluenelabel=Label(root,fg='#0000FF',text="Toluene",width=7).grid(row=13,column=0,sticky="w")
Xylenelabel=Label(root,fg='#0000FF',text="Xylene",width=7).grid(row=14,column=0,sticky="w")
AQIlabel=Label(root,fg='#0000FF',text="AQI",width=7).grid(row=15,column=0,sticky="w")
AQIbucketlabel=Label(root,fg='#0000FF',text="AQIbucket",width=7).grid(row=16,column=0,sticky="w")

citylabel2=Label(root,fg='#0000FF',text="",width=10,bg='#F5DEB3')
citylabel2.grid(row=1,column=1,sticky="w")
Datelabel2=Label(root,fg='#0000FF',text="",width=8)
Datelabel2.grid(row=2,column=1,sticky="w")
PM2label2=Label(root,fg='#0000FF',text="",width=5)
PM2label2.grid(row=3,column=1,sticky="w")
PM10label2=Label(root,fg='#0000FF',text="",width=5)
PM10label2.grid(row=4,column=1,sticky="w")
NOlabel2=Label(root,fg='#0000FF',text="",width=5)
NOlabel2.grid(row=5,column=1,sticky="w")
NO2label2=Label(root,fg='#0000FF',text="",width=5)
NO2label2.grid(row=6,column=1,sticky="w")
Noxlabel2=Label(root,fg='#0000FF',text="",width=5)
Noxlabel2.grid(row=7,column=1,sticky="w")
NH3label2=Label(root,fg='#0000FF',text="",width=5)
NH3label2.grid(row=8,column=1,sticky="w")
COlabel2=Label(root,fg='#0000FF',text="",width=5)
COlabel2.grid(row=9,column=1,sticky="w")
SO2label2=Label(root,fg='#0000FF',text="",width=5)
SO2label2.grid(row=10,column=1,sticky="w")
O3label2=Label(root,fg='#0000FF',text="",width=5)
O3label2.grid(row=11,column=1,sticky="w")
Benzenelabel2=Label(root,fg='#0000FF',text="",width=5)
Benzenelabel2.grid(row=12,column=1,sticky="w")
Toluenelabel2=Label(root,fg='#0000FF',text="",width=5)
Toluenelabel2.grid(row=13,column=1,sticky="w")
Xylenelabel2=Label(root,fg='#0000FF',text="",width=5)
Xylenelabel2.grid(row=14,column=1,sticky="w")
AQIlabel2=Label(root,fg='#0000FF',text="",width=5)
AQIlabel2.grid(row=15,column=1,sticky="w")
AQIbucketlabel2=Label(root,fg='#0000FF',text="",width=8)
AQIbucketlabel2.grid(row=16,column=1,sticky="w")



root.mainloop()
# Out:
# 4
